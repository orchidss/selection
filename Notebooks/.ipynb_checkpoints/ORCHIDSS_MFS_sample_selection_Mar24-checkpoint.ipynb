# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import numpy as np
from scipy.special import erf
from scipy.special import ndtri, ndtr
from tqdm import tqdm

from astropy.table import Table, vstack, Column, join
from astropy.coordinates import SkyCoord, SkyOffsetFrame, Angle
import astropy.units as u

from astropy.cosmology import FlatLambdaCDM
from mocpy import MOC

cos = FlatLambdaCDM(H0=70, Om0=0.3)

import eazy

# Symlink templates & filters from the eazy-code repository
try:
    print('EAZYCODE = '+os.getenv('EAZYCODE'))
except:
    pass

if not os.path.exists('templates'):
    eazy.symlink_eazy_inputs() 

   
# quiet numpy/astropy warnings
import warnings
from astropy.utils.exceptions import AstropyWarning

np.seterr(all='ignore')
warnings.simplefilter('ignore', category=AstropyWarning)

import smpy.smpy as S
from scipy.interpolate import griddata
import astropy.constants as c
from sklearn.neighbors import KNeighborsClassifier

from dustmaps.config import config
config.reset()
from dustmaps.sfd import SFDQuery

def calcflux(SED, wave, filt, units):
    """ Convolve synthetic SEDs with a given filter

    Arguments
    ---------
        SED : numpy.array
            Grid of synthetic spectra
        filt : '~smpy.Filter' class
            Filter through which to convolve SED grid
        z : float
            Redshift at which models are to be observed
        dl : '~astropy.units.Quantity'
            Luminosity distance corresponding to redshift(z) in given
            cosmology.
        units : '~astropy.units'
            Desired output flux units (in spectral flux density)

    Returns
    -------
        Flux : '~astropy.units.Quantity'
            Spectral flux density, with exact units as given by 'units'

    """
    # Find SED wavelength entries within filter range
    wff = np.logical_and(filt.wave[0] < wave,
                         wave < filt.wave[-1])
    wft = wave[wff]

    # Interpolate to find throughput values at new wavelength points
    tpt = griddata(filt.wave, filt.response, wft)

    # Join arrays and sort w.r.t to wf
    # Also replace units stripped by concatenate
    wf = np.array(np.concatenate((filt.wave, wft))) * u.AA
    tp = np.concatenate((filt.response, tpt))

    order = np.argsort(wf)
    wf = wf[order]
    tp = tp[order]

    # Interpolate redshifted SED and LyAbs at new wavelength points
    sed = griddata(wave, SED.T, wf).T * SED.unit
    #lyabs = griddata(wave, self.lyman_abs, wf)

    # Calculate f_nu mean
    # Integrate SED through filter, as per BC03 Fortran
    # As: f_nu=int(dnu Fnu Rnu/h*nu)/int(dnu Rnu/h*nu)
    # ie: f_nu=int(dlm Flm Rlm lm / c)/int(dlm Rlm/lm)
    top = np.trapz(sed * tp * wf /
                   c.c.to(u.AA / u.s), wf)
    bottom = np.trapz(tp / wf, wf)
    #area = (4 * np.pi * (dl ** 2))
    Flux = top / bottom #/ (1 + z) / area

    return Flux.to(units)


def pbelowz(zphot, zerr, zcut):
    dz = zphot - zcut
    sigma_abs = (np.abs(dz)/zerr)

    psigma_abs = ndtr(sigma_abs)
    
    psigma = np.copy(psigma_abs)
    psigma[dz > 0.] = 1-psigma_abs[dz > 0.]
    
    return psigma
# Out:
# EAZYCODE = Users/duncan/Astro/code/eazy-py/eazy-photoz

# %%
mfs = Table.read('../mfs_pointingcentres_2018_radec.txt', format='ascii.commented_header')
mfs_coord = SkyCoord(mfs['RA'], mfs['Dec'], unit='deg')

mfs_mocs = [MOC.from_cone(row.ra, row.dec, radius=30*u.arcmin, max_depth=15) for row in mfs_coord]
mfs_moc = mfs_mocs[0]
for i in range(len(mfs_mocs)-1):
    mfs_moc = mfs_moc.union(mfs_mocs[i+1])
    
#mfs_moc.write('MOCS/MFS_orchidss_wide.moc', overwrite=True)

# %% [markdown]
# ### MeerKAT Fornax

# %%
lsdr8 = Table.read('../lsdr8_mfs_region.fits')

lsdr8_pz = Table.read('../lsdr8pz_mfs_region.fits')
lsdr8_pz_coord = SkyCoord(lsdr8_pz['ra'], lsdr8_pz['dec'], unit='deg')

# %%
lsdr8_morph = Table.read('../lsdr8_mfs_morph.fits')

# %%
in_mfs = mfs_moc.contains(lsdr8_pz_coord.ra, lsdr8_pz_coord.dec)

wide_prob = pbelowz(lsdr8_pz['zphot'], lsdr8_pz['zphot_err'], 0.57)

cut = ((wide_prob > 0.80) * # High photo-z selection probability
       (lsdr8_pz['flag_qual'] == 1) * # Reliable redshift
       (lsdr8_pz['zphot'] > 0.) * # Physical redshift for any missed by above
       in_mfs) # In correct region

lsdr8_merged = join(lsdr8_pz[cut], lsdr8, 
                    keys=['release', 'brickid', 'objid', 'ra', 'dec', 'type'], 
                    join_type='left')
lsdr8_merged = join(lsdr8_merged, lsdr8_morph, 
                    keys=['release', 'brickid', 'objid', 'ra', 'dec', 'type'], 
                    join_type='left')

zmag_tot = 22.5 -2.5*np.log10((lsdr8_merged['flux_z']/lsdr8_merged['mw_transmission_z']))
rmag_tot = 22.5 -2.5*np.log10((lsdr8_merged['flux_r']/lsdr8_merged['mw_transmission_r']))
gmag_tot = 22.5 -2.5*np.log10((lsdr8_merged['flux_g']/lsdr8_merged['mw_transmission_g']))

snr_z = lsdr8_merged['flux_z']*np.sqrt(lsdr8_merged['flux_ivar_z'])

# %%
nanomaggy_to_ujy = 10 ** ((23.9 - 22.5) / 2.5)

filters = ['g', 'r', 'z', 'w1', 'w2', 'w3', 'w4']

eazy_input = lsdr8_merged[['id', 'ra', 'dec', 'type']].copy()

for filt in filters:
    eazy_input[f'flux_{filt}'] = ((lsdr8_merged[f'flux_{filt}'] * nanomaggy_to_ujy) / 
                                      lsdr8_merged[f'mw_transmission_{filt}'])
    eazy_input[f'fluxerr_{filt}'] = (((1/np.sqrt(lsdr8_merged[f'flux_ivar_{filt}'])) * nanomaggy_to_ujy) / 
                                         lsdr8_merged[f'mw_transmission_{filt}'])
    

eazy_input['z_spec'] = lsdr8_merged['zphot']
eazy_input.write('lsdr8_pz_mfs_eazy_input.cat', format='ascii.commented_header', overwrite=True)

# %%
filters = [col.split('_')[1] for col in eazy_input.colnames if col.startswith('flux_')]
print(filters)
# Out:
# ['g', 'r', 'z', 'w1', 'w2', 'w3', 'w4']

# %%
template_sets = ['templates/sfhz/corr_sfhz_13.param']

pzruns = []

for i, templates in enumerate(template_sets[:]):
    params = {}
    params['CATALOG_FILE'] = 'lsdr8_pz_mfs_eazy_input.cat'

    params['MAIN_OUTPUT_FILE'] = 'bc_filters'

    # Galactic extinction
    params['MW_EBV'] = 0.00
    params['CAT_HAS_EXTCORR'] = True

    params['Z_STEP'] = 0.01
    params['Z_MIN'] = 0.0
    params['Z_MAX'] = 0.6
    params['Z_STEP_TYPE'] = 0

    params['SYS_ERR'] = 0.05
    params['APPLY_PRIOR'] = 'N'
    params['PRIOR_FILTER'] = 380
    params['PRIOR_ABZP'] = 23.9 
    params['PRIOR_FILE'] = 'templates/prior_K_TAO.dat'

    params['TEMPLATES_FILE'] = os.path.join('/', os.getenv('EAZYCODE'), templates)
    params['FIX_ZSPEC'] = True

    params['IGM_SCALE_TAU'] = 1.0

    translate_file = os.path.join(os.getenv('EAZYCODE'), 'inputs/zphot.translate')


    translate = Table()
    translate['filt'] = ['id', 'z_spec'] + [col for col in eazy_input.colnames if col.startswith('flux')][:-4]


    translate['num'] = ['id', 'z_spec',
                        'F294', 'E294',
                        'F295', 'E295',
                        'F297', 'E297',
                        'F244', 'E244',
                        'F245', 'E245',
                       ]

    translate_file = os.path.join('/', os.getenv('EAZYCODE'), 'inputs/zphot.translate')

    translate.write(translate_file, format='ascii.no_header', overwrite=True)
    
    pz030 = eazy.photoz.PhotoZ(param_file=None, translate_file=translate_file, 
                               zeropoint_file=None, 
                               params=params, 
                               load_prior=True, load_products=False)

    # Turn off error corrections derived above
    pz030.set_sys_err(positive=True)

    # fit_parallel renamed to fit_catalog 14 May 2021
    pz030.fit_catalog(pz030.idx, n_proc=8)
    
    pzruns.append(pz030)
# Out:
# Read default param file: /Users/duncan/opt/anaconda3/envs/py39/lib/python3.9/site-packages/eazy/data/zphot.param.default
# Read CATALOG_FILE: lsdr8_pz_mfs_eazy_input.cat
#    >>> NOBJ = 170491
# flux_g fluxerr_g (294): DECam/DECam_g.txt
# flux_r fluxerr_r (295): DECam/DECam_r.txt
# flux_z fluxerr_z (297): DECam/DECam_z.txt
# flux_w1 fluxerr_w1 (244): WISE/RSR-W1.txt
# flux_w2 fluxerr_w2 (245): WISE/RSR-W2.txt
# Set sys_err = 0.05 (positive=True)
# Read PRIOR_FILE:  templates/prior_K_TAO.dat
# Template grid: /Users/duncan/Astro/code/eazy-py/eazy-photoz/templates/sfhz/corr_sfhz_13.param (this may take some time)
# 100%|██████████████████████████████████████████████████████████████| 13/13 [00:03<00:00,  3.75it/s]
# Template   0: corr_sfhz_13_bin0_av0.01.fits (NZ=14).
# Template   1: corr_sfhz_13_bin0_av0.25.fits (NZ=14).
# Template   2: corr_sfhz_13_bin0_av0.50.fits (NZ=14).
# Template   3: corr_sfhz_13_bin0_av1.00.fits (NZ=14).
# Template   4: corr_sfhz_13_bin1_av0.01.fits (NZ=14).
# Template   5: corr_sfhz_13_bin1_av0.25.fits (NZ=14).
# Template   6: corr_sfhz_13_bin1_av0.50.fits (NZ=14).
# Template   7: corr_sfhz_13_bin1_av1.00.fits (NZ=14).
# Template   8: corr_sfhz_13_bin2_av0.01.fits (NZ=14).
# Template   9: corr_sfhz_13_bin2_av0.50.fits (NZ=14).
# Template  10: corr_sfhz_13_bin2_av1.00.fits (NZ=14).
# Template  11: corr_sfhz_13_bin3_av0.01.fits (NZ=14).
# Template  12: corr_sfhz_13_bin3_av0.50.fits (NZ=14).
# Process templates: 4.183 s
# 60it [00:00, 83.88it/s]
# Set sys_err = 0.05 (positive=True)
# 100%|██████████████████████████████████████████████████████████████| 60/60 [01:21<00:00,  1.36s/it]
# Compute best fits
# fit_best: 4.9 s (n_proc=8,  NOBJ=170491)
# Fit 87.2 s (n_proc=8, NOBJ=170491)

# %%
rest_output = pz030.rest_frame_fluxes()
# Out:
# Rest-frame filters:
# ~~~~~~~~~~~~~~~~~~~
#    0 REST_FRAME/maiz-apellaniz_Johnson_U.res 2006AJ....131.1184M lambda_c= 3.5900e+03 AB-Vega= 0.769 w95=862.3
#    1 REST_FRAME/maiz-apellaniz_Johnson_B.res 2006AJ....131.1184M lambda_c= 4.3722e+03 AB-Vega=-0.106 w95=1321.3
#    2 REST_FRAME/maiz-apellaniz_Johnson_V.res 2006AJ....131.1184M lambda_c= 5.4794e+03 AB-Vega= 0.002 w95=1369.1
#    3 2MASS/J.res lambda_c= 1.2358e+04 AB-Vega= 0.885 w95=2311.1
#  39%|████████████████████████▌                                      | 7/18 [02:26<02:08, 11.68s/it]/Users/duncan/opt/anaconda3/envs/py39/lib/python3.9/site-packages/eazy/photoz.py:6121: RuntimeWarning: covariance is not positive-semidefinite.
#   draws = np.random.multivariate_normal((coeffs_i*An)[ok_temp],
# 100%|██████████████████████████████████████████████████████████████| 18/18 [05:30<00:00, 18.36s/it]
#  ... rest-frame flux: 330.7 s (n_proc=8,  NOBJ=170491)

# %%
rf_tempfilt, lc_rect, rf_fluxes = rest_output

rf_fluxes_m50 = rf_fluxes[:, :, 2]

uv_col =  -2.5*np.log10(rf_fluxes_m50[:, 0]/rf_fluxes_m50[:, 2])
vj_col =  -2.5*np.log10(rf_fluxes_m50[:, 2]/rf_fluxes_m50[:, 3])

passive = (uv_col > (0.88*vj_col + 0.79)) * (uv_col > 1.3) * (vj_col < 1.6)

Mb = 23.9 - 2.5*np.log10(rf_fluxes_m50[:, 1]) - (cos.distmod(eazy_input['z_spec']).value -2.5*(np.log10(1+eazy_input['z_spec'])))
Mb_st_z = -21 + -1.03*(eazy_input['z_spec'] - 0.5)

dM = 0.7
Mb_cut = Mb < Mb_st_z +dM

mag_r = 23.9 - 2.5*np.log10(lsdr8_merged['flux_r']*nanomaggy_to_ujy)
mag_r_mw = 23.9 - 2.5*np.log10(eazy_input['flux_r'])
mag_z_mw = 23.9 - 2.5*np.log10(eazy_input['flux_z'])

optical_selection = np.logical_or(Mb_cut * np.invert(passive), mag_r_mw < 19.5)

# %%
optical_selection.sum()
# Out:
# 39929

# %%
mfs_area = (mfs_moc.sky_fraction*4*np.pi*u.steradian).to(u.deg**2)

# %%
optical_selection.sum()/mfs_area
# Out:
# <Quantity 1881.06941734 1 / deg2>

# %%
Fig, Ax = plt.subplots(1,1,figsize=(9,6))
plt.hexbin(lsdr8_merged['ra'][optical_selection], lsdr8_merged['dec'][optical_selection], 
           edgecolors=None, gridsize=120)

# %%
mfs_sample = lsdr8_merged[optical_selection]

# %%
extent = np.zeros(len(mfs_sample), dtype='int')
extent_index = np.zeros(len(mfs_sample))
extent_parameter = np.zeros(len(mfs_sample))

# DeV
dev = (mfs_sample['type'] == 'DEV') + ((mfs_sample['type'] == 'COMP') * (mfs_sample['fracdev'] > 0.5))
extent[dev] = 2
extent_index[dev] = 4.0
extent_parameter[dev] = mfs_sample['shapedev_r'][dev]

# EXP
exp = ((mfs_sample['type'] == 'EXP') + (mfs_sample['type'] == 'REX') + 
       ((mfs_sample['type'] == 'COMP') * (mfs_sample['fracdev'] < 0.5)))
extent[exp] = 2
extent_index[exp] = 1.0
extent_parameter[exp] = mfs_sample['shapeexp_r'][exp]

# %%
((mfs_sample['type'] == 'COMP') * (mfs_sample['fracdev'] < 0.5)).sum()
# Out:
# 606

# %%
name = np.array(['MFS_'+str(idn) for idn in mfs_sample['id']])


orchidsswide_mfs = Table()
orchidsswide_mfs['NAME'] = name
orchidsswide_mfs['RA'] = mfs_sample['ra']
orchidsswide_mfs['DEC'] = mfs_sample['dec']
orchidsswide_mfs['MAG'] = 22.5 - 2.5*np.log10(mfs_sample['flux_r'])
orchidsswide_mfs['MAG_ERR'] = 2.5*np.log10(np.e) * 1/(mfs_sample['flux_r']*np.sqrt(mfs_sample['flux_ivar_r']))
orchidsswide_mfs['MAG_TYPE'] = 'DECam_r_AB'
orchidsswide_mfs['REDSHIFT_ESTIMATE'] = mfs_sample['zphot']
orchidsswide_mfs['REDSHIFT_ERROR'] = mfs_sample['zphot_err']

orchidsswide_mfs['EXTENT_FLAG'] = extent
orchidsswide_mfs['EXTENT_INDEX'] = extent_index
orchidsswide_mfs['EXTENT_PARAMETER'] = extent_parameter

# %%
orchidsswide_mfs['flux_g'] = mfs_sample['flux_g']*3.631
orchidsswide_mfs['fluxerr_g'] = 1/np.sqrt(mfs_sample['flux_ivar_g'])*3.631

orchidsswide_mfs['flux_r'] = mfs_sample['flux_r']*3.631
orchidsswide_mfs['fluxerr_r'] = 1/np.sqrt(mfs_sample['flux_ivar_r'])*3.631

orchidsswide_mfs['flux_z'] = mfs_sample['flux_z']*3.631
orchidsswide_mfs['fluxerr_z'] = 1/np.sqrt(mfs_sample['flux_ivar_z'])*3.631

orchidsswide_mfs['flux_w1'] = mfs_sample['flux_w1']*3.631
orchidsswide_mfs['fluxerr_w1'] = 1/np.sqrt(mfs_sample['flux_ivar_w1'])*3.631

orchidsswide_mfs['flux_w2'] = mfs_sample['flux_w2']*3.631
orchidsswide_mfs['fluxerr_w2'] = 1/np.sqrt(mfs_sample['flux_ivar_w2'])*3.631

# %% [markdown]
# ### Add EBV

# %%
scoord = SkyCoord(orchidsswide_mfs['RA']*u.deg, orchidsswide_mfs['DEC']*u.deg)

sfd = SFDQuery()
ebv = sfd(scoord)

orchidsswide_mfs['REDDENING'] = ebv

# %% [markdown]
# ### Template Matching

# %%
filtset = S.LoadEAZYFilters('FILTER.RES.latest')

filters = S.FilterSet()
filters.addEAZYFilter(filtset, [152, 153, 154, 160])

templist = Table.read('../../templates/S7_temps_FINAL/S7_temps_FINALprops.csv')
templist = templist[templist['veldisp'] == 45]

temp_seds = []

for i, tempName in enumerate(tqdm(templist["tempName"][:])):
    temp = Table.read(f'../../templates/S7_temps_FINAL/{tempName}.fits')
    
    if i == 0:
        temp_lambda = temp["LAMBDA"]
        
    temp_seds.append(temp["FLUX_DENSITY"])

temp_seds = np.array(temp_seds)*temp_seds[0].unit

temp_fluxes = []
for filt in filters.filters[:-1]:
    fluxes = calcflux(temp_seds, temp_lambda, filt, units=u.uJy)
    temp_fluxes.append(fluxes)
    
temp_fluxes = np.array(temp_fluxes)*u.uJy
# Out:
# 100%|███████████████████████████████████████████████████████████| 405/405 [00:01<00:00, 241.21it/s]

# %%
sps_fit = pz030.sps_parameters(cosmology=cos, extra_rf_filters=[], percentile_limits=[16, 50, 84], n_proc=8)

cat_ssfr = np.log10(sps_fit['sfr']/sps_fit['mass'])
cat_av = sps_fit['Av']

temp_ssfr = np.log10(templist['SFR']/10**(templist['logmstar']))
temp_av = templist['tau_screen'] * 1.0857

# plt.scatter(cat_ssfr[optical_selection], cat_av[optical_selection],s=3, alpha=0.3)
# plt.scatter(temp_ssfr, temp_av)
# plt.xlim([-16, -7.5])
# Out:
#  44%|████████████████████████████                                   | 8/18 [02:59<02:26, 14.68s/it]/Users/duncan/opt/anaconda3/envs/py39/lib/python3.9/site-packages/eazy/photoz.py:6121: RuntimeWarning: covariance is not positive-semidefinite.
#   draws = np.random.multivariate_normal((coeffs_i*An)[ok_temp],
# 100%|██████████████████████████████████████████████████████████████| 18/18 [05:42<00:00, 19.02s/it]
#  ... rest-frame flux: 342.5 s (n_proc=8,  NOBJ=170491)
# (-16.0, -7.5)

# %%
X = np.array([temp_ssfr, temp_av, temp_uv]).T
X[np.isinf(X)] = -100 
y = np.arange(len(temp_ssfr))

x_in = np.array([cat_ssfr, cat_av, cat_uv]).T[optical_selection]

x_in[x_in[:,0] < -13, 0] = -16.
x_in[np.isnan(x_in[:,2]), 2] = np.nanmean(x_in[:,2])

knn = KNeighborsClassifier(n_neighbors=1).fit(X, y)

temp_match = knn.predict(x_in)
# Out:
# /Users/duncan/opt/anaconda3/envs/py39/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
orchidsswide_mfs['TEMPLATE'] = templist['tempName'][temp_match]
orchidsswide_mfs['FIELD'] = 'MFS'

# %%
orchidsswide_mfs.write('ORCHIDSSwide-mfs_20240413.fits', format='fits', overwrite=True)

# %%
# cat_uv = -2.5*np.log10(rf_fluxes_m50[:,0]/rf_fluxes_m50[:,2])
# cat_bv = -2.5*np.log10(rf_fluxes_m50[:,1]/rf_fluxes_m50[:,2])

# temp_ub = -2.5*np.log10(temp_fluxes[0]/temp_fluxes[1])
# temp_bv = -2.5*np.log10(temp_fluxes[1]/temp_fluxes[2])
# temp_uv = -2.5*np.log10(temp_fluxes[0]/tempa_fluxes[2])


# plt.scatter(cat_bv[optical_selection], cat_ub[optical_selection], s=2)
# plt.scatter(temp_bv, temp_ub)
# plt.ylim([-0.5, 2])
# Out:
# (-0.5, 2.0)

# %%
rlim = 21.5
orchidsswide_mfs_old = Table.read(f'../../codes/20230305/WAVES_ORCHIDSSwide_MFS_LSDR8_r{rlim}_z0.57.fits')

# %%
orchidsswide_mfs_old
# Out:
# <Table length=103018>
#         NAME                 RA                 DEC         ... FIELD   REDDENING
#       bytes20             float64             float64       ... bytes3   float32
# -------------------- ------------------ ------------------- ... ------ ------------
# MFS_8000124934005950  50.63301730143956  -38.40144348247811 ...    MFS  0.017171225
# MFS_8000124934006127  50.61132305389904  -38.39525090731894 ...    MFS  0.017441103
# MFS_8000124934006205 50.606244127913854  -38.39212511916561 ...    MFS  0.017474217
# MFS_8000124934006267  50.59204630108839  -38.38821146469123 ...    MFS  0.017704284
# MFS_8000124934006442  50.59788498571491  -38.38222041951474 ...    MFS  0.017398126
# MFS_8000124934006536 50.567399982876395  -38.37757767885163 ...    MFS  0.017897183
# MFS_8000124934006571 50.630341764313954 -38.376045164615945 ...    MFS  0.016379187
# MFS_8000124935004441  50.94726033224596  -38.47235800168786 ...    MFS  0.015444328
# MFS_8000124935004503   50.9554215649044 -38.468253958497776 ...    MFS  0.015507469
# MFS_8000124935004623 50.856226586072026 -38.461877379839656 ...    MFS  0.015660917
# MFS_8000124935004645  50.95824586624464  -38.46174359221107 ...    MFS  0.015536106
# MFS_8000124935004652  50.93895795201632  -38.46243381178439 ...    MFS  0.015528023
# MFS_8000124935004698  50.94331554535585 -38.455774264732014 ...    MFS  0.015612921
# MFS_8000124935004709 50.946817697154444  -38.45716064891457 ...    MFS  0.015578174
# MFS_8000124935004713  50.89234963589449  -38.45801926472419 ...    MFS  0.015546414
# MFS_8000124935004728  50.84392619040491  -38.45770666906095 ...    MFS  0.015700215
# MFS_8000124935004740  50.86302903687329  -38.45412740046033 ...    MFS  0.015570599
# MFS_8000124935004742  50.86086728087218  -38.45589498806285 ...    MFS  0.015595321
# MFS_8000124935004810 50.881316523081715  -38.45345841541409 ...    MFS  0.015585692
# MFS_8000124935004824   50.7992430367944  -38.45415624859479 ...    MFS  0.015935848
# MFS_8000124935004851  50.79071986564905 -38.451839648968345 ...    MFS  0.016017305
# MFS_8000124935004866  50.95787383222749 -38.451121277967836 ...    MFS  0.015612696
# MFS_8000124935004887  50.94222000599194  -38.44868930356205 ...    MFS  0.015735632
# MFS_8000124935004891  50.91327394791498  -38.45072887849481 ...    MFS  0.015743447
# MFS_8000124935004931 50.882382044754394 -38.448424676020416 ...    MFS  0.015687518
# MFS_8000124935004964  50.83624181220008 -38.447763987593675 ...    MFS  0.015705582
# MFS_8000124935005061  50.85589230074142  -38.44359881388468 ...    MFS  0.015668528
# MFS_8000124935005073  50.91764840549342  -38.44252421820039 ...    MFS   0.01591208
# MFS_8000124935005132 50.864831743064904  -38.43937813814362 ...    MFS  0.015785005
# MFS_8000124935005153   50.7685887079024  -38.43674401858617 ...    MFS  0.016092947
# MFS_8000124935005154  50.77148121929532  -38.43753533894705 ...    MFS  0.016091414
# MFS_8000124935005160   50.9375897495986  -38.43914532430964 ...    MFS   0.01592181
#                  ...                ...                 ... ...    ...          ...
# MFS_8000148274003583 55.144162655550915 -33.509938618224034 ...    MFS 0.0075223064
# MFS_8000148274003640 55.070499032208865   -33.5083187924797 ...    MFS  0.007997464
# MFS_8000148274003646 55.159757024928766  -33.50744396132042 ...    MFS 0.0073886127
# MFS_8000148274003655  55.05406591647544  -33.50786650733146 ...    MFS  0.008054228
# MFS_8000148274003668   55.0654075080043 -33.507583524307755 ...    MFS  0.008023038
# MFS_8000148274003696 55.192970791006395  -33.50690893629606 ...    MFS 0.0070058326
# MFS_8000148274003722 55.093705367169754  -33.50581310030349 ...    MFS  0.007872793
# MFS_8000148274003791  55.05624654355609 -33.502874272504165 ...    MFS 0.0080861915
# MFS_8000148274003852 55.150119676440696 -33.500888612460315 ...    MFS  0.007481432
# MFS_8000148274003874  55.02880775980149  -33.49640962371556 ...    MFS  0.008169745
# MFS_8000148274003886 55.057584818612376  -33.50005516827674 ...    MFS  0.008101519
# MFS_8000148274003887   55.1599682149897 -33.500709396918374 ...    MFS 0.0073824404
# MFS_8000148274003888  55.10324731799865   -33.4985690519121 ...    MFS  0.007834255
# MFS_8000148274003916  55.09559964552397  -33.50013281276845 ...    MFS  0.007876797
# MFS_8000148274004091 55.145629624002176    -33.490343324586 ...    MFS 0.0075284997
# MFS_8000148274004092  55.14606350701748 -33.492061463549625 ...    MFS  0.007522706
# MFS_8000148274004101 55.171765933461245   -33.4918883377319 ...    MFS 0.0072540427
# MFS_8000148274004397  55.12737009034847  -33.48215380911159 ...    MFS  0.007705788
# MFS_8000148274004444  55.03971229844642   -33.4797978577045 ...    MFS  0.008297271
# MFS_8000148274004451  55.13900277036384  -33.48116390742404 ...    MFS  0.007605376
# MFS_8000148274004561  55.06560530177445  -33.47735912373973 ...    MFS  0.008187037
# MFS_8000148274004699 55.117212130697276  -33.47284557241878 ...    MFS  0.007819429
# MFS_8000148274004712 55.037770117585914  -33.47185007334362 ...    MFS  0.008356666
# MFS_8000148274004716  55.10312606583629  -33.47199736355128 ...    MFS  0.007950569
# MFS_8000148274004875   55.0395767362698  -33.46610097658767 ...    MFS  0.008394887
# MFS_8000148274004994  55.01786227250055 -33.459727548723414 ...    MFS   0.00851471
# MFS_8000148274004995   55.0202238333142  -33.46217943657861 ...    MFS  0.008485793
# MFS_8000148274005130 55.051025752196445 -33.457655705096585 ...    MFS  0.008417583
# MFS_8000148274005152  55.06598761823582 -33.453629365637894 ...    MFS  0.008369976
# MFS_8000148274005194  55.07382081769127  -33.45476882183621 ...    MFS  0.008311164
# MFS_8000148274005201 55.020214114298945   -33.4543385708163 ...    MFS  0.008565116
# MFS_8000148274005333  55.05215962081515 -33.450725014219906 ...    MFS  0.008475761
# MFS_8000148275000020  55.33561134073577  -33.62439728197916 ...    MFS  0.005272704

# %%
plt.hist(orchidsswide_mfs_old['MAG'], range=(16, 21.8), bins=100)
plt.hist(orchidsswide_mfs['MAG'], range=(16,21.8), bins=100)
# Out:
# (array([   7.,    5.,    8.,   14.,   12.,   18.,   11.,   20.,   12.,
#           23.,   25.,   31.,   38.,   24.,   39.,   38.,   24.,   51.,
#           47.,   53.,   60.,   63.,   81.,   87.,   78.,  101.,  104.,
#          116.,  118.,  122.,  142.,  132.,  157.,  178.,  172.,  204.,
#          210.,  250.,  263.,  277.,  287.,  323.,  325.,  359.,  365.,
#          403.,  424.,  450.,  425.,  520.,  573.,  556.,  619.,  656.,
#          691.,  730.,  793.,  830.,  899.,  947.,  893.,  446.,  462.,
#          458.,  468.,  504.,  531.,  563.,  603.,  598.,  594.,  644.,
#          673.,  732.,  763.,  775.,  793.,  804.,  898.,  861.,  910.,
#          984.,  935.,  929., 1023.,  931.,  867.,  907.,  831.,  703.,
#          777.,  631.,  552.,  452.,  335.,  229.,  140.,   63.,   23.,
#            6.]),
#  array([16.   , 16.058, 16.116, 16.174, 16.232, 16.29 , 16.348, 16.406,
#         16.464, 16.522, 16.58 , 16.638, 16.696, 16.754, 16.812, 16.87 ,
#         16.928, 16.986, 17.044, 17.102, 17.16 , 17.218, 17.276, 17.334,
#         17.392, 17.45 , 17.508, 17.566, 17.624, 17.682, 17.74 , 17.798,
#         17.856, 17.914, 17.972, 18.03 , 18.088, 18.146, 18.204, 18.262,
#         18.32 , 18.378, 18.436, 18.494, 18.552, 18.61 , 18.668, 18.726,
#         18.784, 18.842, 18.9  , 18.958, 19.016, 19.074, 19.132, 19.19 ,
#         19.248, 19.306, 19.364, 19.422, 19.48 , 19.538, 19.596, 19.654,
#         19.712, 19.77 , 19.828, 19.886, 19.944, 20.002, 20.06 , 20.118,
#         20.176, 20.234, 20.292, 20.35 , 20.408, 20.466, 20.524, 20.582,
#         20.64 , 20.698, 20.756, 20.814, 20.872, 20.93 , 20.988, 21.046,
#         21.104, 21.162, 21.22 , 21.278, 21.336, 21.394, 21.452, 21.51 ,
#         21.568, 21.626, 21.684, 21.742, 21.8  ], dtype=float32),
#  <BarContainer object of 100 artists>)

# %%
plt.scatter(orchidsswide_mfs['REDSHIFT_ESTIMATE'], orchidsswide_mfs['MAG'], s=3, alpha=0.1)
plt.ylim([15., 22.])
# Out:
# (15.0, 22.0)

# %%
fig = plt.figure(figsize=(8, 5))

mfs_ra_mean = np.mean(mfs_coord.ra.value)
mfs_dec_mean = np.mean(mfs_coord.dec.value)

# Define a astropy WCS easily
with World2ScreenMPL(fig, 
        fov=9.0 * u.deg,
        center=SkyCoord(mfs_ra_mean, mfs_dec_mean, unit='deg', frame='icrs'),
        coordsys="icrs",
        rotation=Angle(0, u.degree),
        projection="AIT") as wcs:
    
    ax = fig.add_subplot(1, 1, 1, projection=wcs)
    ax.plot(orchidsswide_mfs['RA'][magcut]*u.deg, orchidsswide_mfs['DEC'][magcut]*u.deg, 'o', ms=1, alpha=0.3,
            transform=ax.get_transform('world'), color='darkolivegreen', rasterized=True)
    
    # Call fill with a matplotlib axe and the `~astropy.wcs.WCS` wcs object.
#     xmm_lsst_moc.border(ax=ax, wcs=wcs, alpha=1, lw=2, color="firebrick", label='LSST DDF')
#     xmm_ddf_moc.border(ax=ax, wcs=wcs, alpha=1, lw=2, color="black", label='WAVES DDF')
    mfs_moc.border(ax=ax, wcs=wcs, alpha=1, lw=3, color="orchid", label='MFS')

fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">
